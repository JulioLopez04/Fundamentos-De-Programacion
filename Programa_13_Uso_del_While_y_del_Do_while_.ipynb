# %% [markdown]
# JCLM ITSLP F.P. 05-11-2025 - Dos programas, el primer programa es una prueba para ver como funciona el while, imprimiendo el numero de vueltas de este; el segundo programa simula el uso de do while que no existe en python, y este lo aplica en el caso de cuando ingresamos una contraseña para iniciar sesión, con la posibilidad de tener 4 intentos

# %% [markdown]
# *Programa 1*

# %%
#Inicio
#Declara las variales
Contador = int(0)

#Mientras que la condicion sea verdadera
while Contador < 10:
  print("Es la vuelta:", Contador)
  Contador = Contador + 1
#Fin
# Out:
# Es la vuelta: 0
# Es la vuelta: 1
# Es la vuelta: 2
# Es la vuelta: 3
# Es la vuelta: 4
# Es la vuelta: 5
# Es la vuelta: 6
# Es la vuelta: 7
# Es la vuelta: 8
# Es la vuelta: 9

# %% [markdown]
# *Programa 2*

# %%
#inicio
#Uso del Do while como si fuera una contraseña
#Declarar las variables
Cont = int(0)
Contraseña = str("tec12345")
#Vamos a emular el Do while
#Mientras que la condicion sea verdadera
while True:
  Contraseña = input("Ingrese la contraseña, solo tienes cuatro intentos: ")
  if Contraseña == "tec12345":
    print("Sesión iniciada")
    break
  elif Cont < 3:
    Cont = Cont + 1
    print("Contraseña incorrecta")
  else:
    print("Sesión bloqueada")
    break
#Fin
# Out:
# Ingrese la contraseña, solo tienes cuatro intentos: tec12345
# Sesión iniciada
